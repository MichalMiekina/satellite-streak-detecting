# %%
import os
import cv2
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from datetime import datetime
from tensorflow.keras.applications import ResNet50
from sklearn.metrics import precision_score, recall_score, f1_score

def calculate_metrics(stats_df):
    correct_predictions = stats_df[stats_df['ground_truth'] == stats_df['cnn_prediction']]
    accuracy = len(correct_predictions) / len(stats_df)
    precision = precision_score(stats_df['ground_truth'], stats_df['cnn_prediction'])
    recall = recall_score(stats_df['ground_truth'], stats_df['cnn_prediction'])
    f1 = f1_score(stats_df['ground_truth'], stats_df['cnn_prediction'])
    return accuracy, precision, recall, f1

def serialize_model(model, accuracy):
    if accuracy >= 0.80:
        current_datetime = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
        model_filename = f"trained_model_{current_datetime}.h5"
        model.save(model_filename)
        print("Model serialized successfully. Model saved as:", model_filename)
        return model_filename
    else:
        return None

def preprocess_png(image_path):
    image = cv2.imread(image_path)
    resized_image = cv2.resize(image, (224, 224))
    preprocessed_image = np.expand_dims(resized_image, axis=0)
    return preprocessed_image

def detect_lines_cnn(image_path, model):
    preprocessed_image = preprocess_png(image_path)
    prediction = model.predict(preprocessed_image, verbose=0)[0][0]
    if prediction >= 0.5:
        return True, prediction
    else:
        return False, prediction

def find_latest_dictionary_csv(folder_path):
    csv_files = [f for f in os.listdir(folder_path) if f.startswith('dictionary') and f.endswith('.csv')]
    if not csv_files:
        print("No dictionary CSV file found.")
        return None
    latest_csv = max(csv_files)
    return latest_csv

def load_dictionary(folder_path):
    latest_dictionary_csv = find_latest_dictionary_csv(folder_path)
    if latest_dictionary_csv:
        dictionary_df = pd.read_csv(os.path.join(folder_path, latest_dictionary_csv))
        return dictionary_df
    else:
        print("Exiting program.")
        exit()

def read_png_data(folder_path, dictionary_df, model):
    filenames = []
    ground_truth = []
    cnn_predictions = []
    cnn_raw_predictions = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.png'):
            image_path = os.path.join(folder_path, filename)
            matching_row = dictionary_df[dictionary_df['output'] == filename]
            if len(matching_row) == 0:
                print(f"No label found for filename: {filename}")
                continue
            label = matching_row.iloc[0]['label']
            ground_truth.append(label)
            cnn_prediction, cnn_raw_prediction = detect_lines_cnn(image_path, model)
            cnn_predictions.append(cnn_prediction)
            cnn_raw_predictions.append(cnn_raw_prediction)
            filenames.append(filename)
    return pd.DataFrame({
        'filename': filenames,
        'ground_truth': ground_truth,
        'cnn_prediction': cnn_predictions,
        'cnn_raw_prediction': cnn_raw_predictions
    })

def save_metrics_to_csv(metrics_list):
    current_datetime = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    csv_filename = f"model_metrics_resnet_{current_datetime}.csv"
    metrics_df = pd.DataFrame(metrics_list, columns=['Accuracy', 'Precision', 'Recall', 'F1'])
    metrics_df.to_csv(csv_filename, index=False)
    print("Model metrics saved to:", csv_filename)

def display_prediction_table(stats_df):
    print("Files in the checking folder:")
    print(stats_df)


folder_path = './Data/fits_filtered5/'

metrics_list = []

for i in range(10):
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    for layer in base_model.layers:
        layer.trainable = False

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(256, activation='relu')(x)
    predictions = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

    dictionary_df = load_dictionary(folder_path)
    stats_df = read_png_data(folder_path, dictionary_df, model)

    accuracy, precision, recall, f1 = calculate_metrics(stats_df)

    print(f"Iteration {i+1}: CNN Model Metrics - Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1: {f1}")
    model_filename = serialize_model(model, accuracy)
    metrics_list.append({'Accuracy': accuracy, 'Precision': precision, 'Recall': recall, 'F1': f1})

    display_prediction_table(stats_df)

# Save the list of metrics to a CSV file
save_metrics_to_csv(metrics_list)
# Out:
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Python310\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Iteration 1: CNN Model Metrics - Accuracy: 0.4411764705882353, Precision: 0.45454545454545453, Recall: 0.9375, F1: 0.6122448979591837
# Files in the checking folder:
#      filename  ground_truth  cnn_prediction  cnn_raw_prediction
# 0    tic1.png             1            True            0.589151
# 1   tic10.png             1            True            0.784400
# 2   tic11.png             1            True            0.775381
# 3   tic12.png             1            True            0.906788
# 4   tic13.png             1            True            0.726234
# 5   tic14.png             1            True            0.773550
# 6   tic15.png             1            True            0.712657
# 7   tic16.png             1            True            0.519825
# 8   tic17.png             1            True            0.690515
# 9   tic18.png             1            True            0.701668
# 10  tic19.png             0            True            0.892983
# 11   tic2.png             1            True            0.683661
# 12  tic20.png             0            True            0.722571
# 13  tic21.png             0            True            0.764628
# 14  tic22.png             0            True            0.770714
# 15  tic23.png             0            True            0.786049
# 16  tic24.png             0            True            0.826186
# 17  tic25.png             0            True            0.806567
# 18  tic26.png             0            True            0.814736
# 19  tic27.png             1            True            0.910628
# 20  tic28.png             1            True            0.835678
# 21  tic29.png             1            True            0.834165
# 22   tic3.png             1            True            0.794458
# 23  tic30.png             0            True            0.924725
# 24  tic31.png             0            True            0.871520
# 25  tic32.png             0            True            0.872561
# 26  tic33.png             0            True            0.723755
# 27  tic34.png             0            True            0.690457
# 28   tic4.png             0            True            0.892458
# 29   tic5.png             0            True            0.875788
# 30   tic6.png             1           False            0.405091
# 31   tic7.png             0            True            0.880068
# 32   tic8.png             0            True            0.884109
# 33   tic9.png             0            True            0.888890
# Iteration 2: CNN Model Metrics - Accuracy: 0.7058823529411765, Precision: 0.75, Recall: 0.5625, F1: 0.6428571428571429
# Files in the checking folder:
#      filename  ground_truth  cnn_prediction  cnn_raw_prediction
# 0    tic1.png             1            True            0.666368
# 1   tic10.png             1           False            0.492735
# 2   tic11.png             1           False            0.467284
# 3   tic12.png             1           False            0.406238
# 4   tic13.png             1           False            0.468012
# 5   tic14.png             1            True            0.614429
# 6   tic15.png             1            True            0.500465
# 7   tic16.png             1            True            0.619766
# 8   tic17.png             1            True            0.503082
# 9   tic18.png             1            True            0.579412
# 10  tic19.png             0            True            0.591318
# 11   tic2.png             1            True            0.690496
# 12  tic20.png             0            True            0.546312
# 13  tic21.png             0            True            0.543331
# 14  tic22.png             0           False            0.489290
# 15  tic23.png             0           False            0.392799
# 16  tic24.png             0           False            0.464564
# 17  tic25.png             0           False            0.492295
# 18  tic26.png             0           False            0.468712
# 19  tic27.png             1           False            0.447194
# 20  tic28.png             1           False            0.454881
# 21  tic29.png             1           False            0.432841
# 22   tic3.png             1            True            0.615353
# 23  tic30.png             0           False            0.391761
# 24  tic31.png             0           False            0.373416
# 25  tic32.png             0           False            0.435988
# 26  tic33.png             0           False            0.477567
# 27  tic34.png             0           False            0.462865
# 28   tic4.png             0           False            0.368962
# 29   tic5.png             0           False            0.455716
# 30   tic6.png             1            True            0.619073
# 31   tic7.png             0           False            0.413377
# 32   tic8.png             0           False            0.279382
# 33   tic9.png             0           False            0.470052
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Iteration 3: CNN Model Metrics - Accuracy: 0.5294117647058824, Precision: 0.0, Recall: 0.0, F1: 0.0
# Files in the checking folder:
#      filename  ground_truth  cnn_prediction  cnn_raw_prediction
# 0    tic1.png             1           False            0.186389
# 1   tic10.png             1           False            0.170796
# 2   tic11.png             1           False            0.182574
# 3   tic12.png             1           False            0.281542
# 4   tic13.png             1           False            0.270519
# 5   tic14.png             1           False            0.301611
# 6   tic15.png             1           False            0.288639
# 7   tic16.png             1           False            0.283345
# 8   tic17.png             1           False            0.221111
# 9   tic18.png             1           False            0.257572
# 10  tic19.png             0           False            0.446804
# 11   tic2.png             1           False            0.222368
# 12  tic20.png             0           False            0.212160
# 13  tic21.png             0           False            0.273051
# 14  tic22.png             0           False            0.340871
# 15  tic23.png             0           False            0.101011
# 16  tic24.png             0           False            0.227893
# 17  tic25.png             0           False            0.209090
# 18  tic26.png             0           False            0.239931
# 19  tic27.png             1           False            0.246932
# 20  tic28.png             1           False            0.231127
# 21  tic29.png             1           False            0.220091
# 22   tic3.png             1           False            0.367721
# 23  tic30.png             0           False            0.236638
# 24  tic31.png             0           False            0.224661
# 25  tic32.png             0           False            0.214408
# 26  tic33.png             0           False            0.271822
# 27  tic34.png             0           False            0.282772
# 28   tic4.png             0           False            0.234708
# 29   tic5.png             0           False            0.261831
# 30   tic6.png             1           False            0.303366
# 31   tic7.png             0           False            0.229653
# 32   tic8.png             0           False            0.251118
# 33   tic9.png             0           False            0.277558
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Iteration 4: CNN Model Metrics - Accuracy: 0.5294117647058824, Precision: 0.0, Recall: 0.0, F1: 0.0
# Files in the checking folder:
#      filename  ground_truth  cnn_prediction  cnn_raw_prediction
# 0    tic1.png             1           False            0.126775
# 1   tic10.png             1           False            0.137864
# 2   tic11.png             1           False            0.126132
# 3   tic12.png             1           False            0.223734
# 4   tic13.png             1           False            0.137303
# 5   tic14.png             1           False            0.213413
# 6   tic15.png             1           False            0.146210
# 7   tic16.png             1           False            0.145885
# 8   tic17.png             1           False            0.167266
# 9   tic18.png             1           False            0.195230
# 10  tic19.png             0           False            0.271001
# 11   tic2.png             1           False            0.167394
# 12  tic20.png             0           False            0.145276
# 13  tic21.png             0           False            0.214161
# 14  tic22.png             0           False            0.173188
# 15  tic23.png             0           False            0.221435
# 16  tic24.png             0           False            0.178065
# 17  tic25.png             0           False            0.136106
# 18  tic26.png             0           False            0.162156
# 19  tic27.png             1           False            0.273628
# 20  tic28.png             1           False            0.234549
# 21  tic29.png             1           False            0.225308
# 22   tic3.png             1           False            0.249182
# 23  tic30.png             0           False            0.276975
# 24  tic31.png             0           False            0.248528
# 25  tic32.png             0           False            0.245365
# 26  tic33.png             0           False            0.141273
# 27  tic34.png             0           False            0.138146
# 28   tic4.png             0           False            0.244042
# 29   tic5.png             0           False            0.263945
# 30   tic6.png             1           False            0.040493
# 31   tic7.png             0           False            0.230446
# 32   tic8.png             0           False            0.332451
# 33   tic9.png             0           False            0.208129
# Iteration 5: CNN Model Metrics - Accuracy: 0.4411764705882353, Precision: 0.4482758620689655, Recall: 0.8125, F1: 0.5777777777777777
# Files in the checking folder:
#      filename  ground_truth  cnn_prediction  cnn_raw_prediction
# 0    tic1.png             1            True            0.569908
# 1   tic10.png             1            True            0.675703
# 2   tic11.png             1            True            0.704854
# 3   tic12.png             1            True            0.572865
# 4   tic13.png             1            True            0.514323
# 5   tic14.png             1            True            0.613222
# 6   tic15.png             1           False            0.495889
# 7   tic16.png             1            True            0.637339
# 8   tic17.png             1            True            0.609925
# 9   tic18.png             1            True            0.581092
# 10  tic19.png             0            True            0.579582
# 11   tic2.png             1            True            0.563942
# 12  tic20.png             0            True            0.561413
# 13  tic21.png             0            True            0.627831
# 14  tic22.png             0            True            0.564052
# 15  tic23.png             0            True            0.517150
# 16  tic24.png             0            True            0.694792
# 17  tic25.png             0            True            0.673387
# 18  tic26.png             0            True            0.715713
# 19  tic27.png             1            True            0.531657
# 20  tic28.png             1           False            0.477990
# 21  tic29.png             1           False            0.484396
# 22   tic3.png             1            True            0.569988
# 23  tic30.png             0            True            0.555037
# 24  tic31.png             0           False            0.444630
# 25  tic32.png             0            True            0.521733
# 26  tic33.png             0            True            0.505447
# 27  tic34.png             0           False            0.489133
# 28   tic4.png             0            True            0.520296
# 29   tic5.png             0            True            0.540779
# 30   tic6.png             1            True            0.753812
# 31   tic7.png             0            True            0.519334
# 32   tic8.png             0            True            0.608771
# 33   tic9.png             0            True            0.660097
# Iteration 6: CNN Model Metrics - Accuracy: 0.47058823529411764, Precision: 0.47058823529411764, Recall: 1.0, F1: 0.6399999999999999
# Files in the checking folder:
#      filename  ground_truth  cnn_prediction  cnn_raw_prediction
# 0    tic1.png             1            True            0.766590
# 1   tic10.png             1            True            0.774658
# 2   tic11.png             1            True            0.798821
# 3   tic12.png             1            True            0.777622
# 4   tic13.png             1            True            0.701447
# 5   tic14.png             1            True            0.764943
# 6   tic15.png             1            True            0.704235
# 7   tic16.png             1            True            0.721941
# 8   tic17.png             1            True            0.744581
# 9   tic18.png             1            True            0.676114
# 10  tic19.png             0            True            0.678762
# 11   tic2.png             1            True            0.763029
# 12  tic20.png             0            True            0.737649
# 13  tic21.png             0            True            0.666894
# 14  tic22.png             0            True            0.633101
# 15  tic23.png             0            True            0.533085
# 16  tic24.png             0            True            0.752822
# 17  tic25.png             0            True            0.734623
# 18  tic26.png             0            True            0.757044
# 19  tic27.png             1            True            0.660851
# 20  tic28.png             1            True            0.665465
# 21  tic29.png             1            True            0.664047
# 22   tic3.png             1            True            0.722809
# 23  tic30.png             0            True            0.746097
# 24  tic31.png             0            True            0.662558
# 25  tic32.png             0            True            0.640458
# 26  tic33.png             0            True            0.745984
# 27  tic34.png             0            True            0.738022
# 28   tic4.png             0            True            0.666612
# 29   tic5.png             0            True            0.728640
# 30   tic6.png             1            True            0.653285
# 31   tic7.png             0            True            0.582136
# 32   tic8.png             0            True            0.722421
# 33   tic9.png             0            True            0.733323
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Iteration 7: CNN Model Metrics - Accuracy: 0.5294117647058824, Precision: 0.0, Recall: 0.0, F1: 0.0
# Files in the checking folder:
#      filename  ground_truth  cnn_prediction  cnn_raw_prediction
# 0    tic1.png             1           False            0.389790
# 1   tic10.png             1           False            0.417005
# 2   tic11.png             1           False            0.363822
# 3   tic12.png             1           False            0.219314
# 4   tic13.png             1           False            0.254321
# 5   tic14.png             1           False            0.196956
# 6   tic15.png             1           False            0.279938
# 7   tic16.png             1           False            0.279408
# 8   tic17.png             1           False            0.286370
# 9   tic18.png             1           False            0.410592
# 10  tic19.png             0           False            0.285241
# 11   tic2.png             1           False            0.243721
# 12  tic20.png             0           False            0.240791
# 13  tic21.png             0           False            0.262574
# 14  tic22.png             0           False            0.329871
# 15  tic23.png             0           False            0.348205
# 16  tic24.png             0           False            0.351290
# 17  tic25.png             0           False            0.407574
# 18  tic26.png             0           False            0.371538
# 19  tic27.png             1           False            0.370293
# 20  tic28.png             1           False            0.282880
# 21  tic29.png             1           False            0.337919
# 22   tic3.png             1           False            0.253183
# 23  tic30.png             0           False            0.339791
# 24  tic31.png             0           False            0.323416
# 25  tic32.png             0           False            0.357388
# 26  tic33.png             0           False            0.246378
# 27  tic34.png             0           False            0.284638
# 28   tic4.png             0           False            0.331750
# 29   tic5.png             0           False            0.234341
# 30   tic6.png             1           False            0.117383
# 31   tic7.png             0           False            0.373628
# 32   tic8.png             0           False            0.248702
# 33   tic9.png             0           False            0.373541
# Iteration 8: CNN Model Metrics - Accuracy: 0.4117647058823529, Precision: 0.25, Recall: 0.125, F1: 0.16666666666666666
# Files in the checking folder:
#      filename  ground_truth  cnn_prediction  cnn_raw_prediction
# 0    tic1.png             1           False            0.360736
# 1   tic10.png             1            True            0.503127
# 2   tic11.png             1           False            0.453999
# 3   tic12.png             1            True            0.524451
# 4   tic13.png             1           False            0.299850
# 5   tic14.png             1           False            0.219886
# 6   tic15.png             1           False            0.307790
# 7   tic16.png             1           False            0.376989
# 8   tic17.png             1           False            0.307412
# 9   tic18.png             1           False            0.326286
# 10  tic19.png             0           False            0.277434
# 11   tic2.png             1           False            0.268238
# 12  tic20.png             0           False            0.250602
# 13  tic21.png             0           False            0.289132
# 14  tic22.png             0           False            0.308812
# 15  tic23.png             0           False            0.473923
# 16  tic24.png             0            True            0.519896
# 17  tic25.png             0            True            0.512907
# 18  tic26.png             0            True            0.533619
# 19  tic27.png             1           False            0.404510
# 20  tic28.png             1           False            0.358558
# 21  tic29.png             1           False            0.377994
# 22   tic3.png             1           False            0.341505
# 23  tic30.png             0           False            0.405509
# 24  tic31.png             0           False            0.390732
# 25  tic32.png             0           False            0.366398
# 26  tic33.png             0           False            0.287818
# 27  tic34.png             0           False            0.290935
# 28   tic4.png             0           False            0.411229
# 29   tic5.png             0            True            0.603027
# 30   tic6.png             1           False            0.357471
# 31   tic7.png             0           False            0.380796
# 32   tic8.png             0            True            0.774589
# 33   tic9.png             0            True            0.544590
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Iteration 9: CNN Model Metrics - Accuracy: 0.5294117647058824, Precision: 0.0, Recall: 0.0, F1: 0.0
# Files in the checking folder:
#      filename  ground_truth  cnn_prediction  cnn_raw_prediction
# 0    tic1.png             1           False            0.016393
# 1   tic10.png             1           False            0.028661
# 2   tic11.png             1           False            0.028734
# 3   tic12.png             1           False            0.034806
# 4   tic13.png             1           False            0.014445
# 5   tic14.png             1           False            0.024119
# 6   tic15.png             1           False            0.014790
# 7   tic16.png             1           False            0.015207
# 8   tic17.png             1           False            0.016067
# 9   tic18.png             1           False            0.018336
# 10  tic19.png             0           False            0.027696
# 11   tic2.png             1           False            0.032001
# 12  tic20.png             0           False            0.016770
# 13  tic21.png             0           False            0.021633
# 14  tic22.png             0           False            0.013251
# 15  tic23.png             0           False            0.016356
# 16  tic24.png             0           False            0.027749
# 17  tic25.png             0           False            0.022533
# 18  tic26.png             0           False            0.023882
# 19  tic27.png             1           False            0.026703
# 20  tic28.png             1           False            0.021746
# 21  tic29.png             1           False            0.017734
# 22   tic3.png             1           False            0.021824
# 23  tic30.png             0           False            0.030527
# 24  tic31.png             0           False            0.019000
# 25  tic32.png             0           False            0.017093
# 26  tic33.png             0           False            0.014204
# 27  tic34.png             0           False            0.016850
# 28   tic4.png             0           False            0.021977
# 29   tic5.png             0           False            0.036147
# 30   tic6.png             1           False            0.025402
# 31   tic7.png             0           False            0.017470
# 32   tic8.png             0           False            0.055648
# 33   tic9.png             0           False            0.031416
# Iteration 10: CNN Model Metrics - Accuracy: 0.5294117647058824, Precision: 0.0, Recall: 0.0, F1: 0.0
# Files in the checking folder:
#      filename  ground_truth  cnn_prediction  cnn_raw_prediction
# 0    tic1.png             1           False            0.223435
# 1   tic10.png             1           False            0.273800
# 2   tic11.png             1           False            0.303965
# 3   tic12.png             1           False            0.340667
# 4   tic13.png             1           False            0.300269
# 5   tic14.png             1           False            0.354645
# 6   tic15.png             1           False            0.274058
# 7   tic16.png             1           False            0.335740
# 8   tic17.png             1           False            0.260331
# 9   tic18.png             1           False            0.279632
# 10  tic19.png             0           False            0.350959
# 11   tic2.png             1           False            0.312170
# 12  tic20.png             0           False            0.283221
# 13  tic21.png             0           False            0.295520
# 14  tic22.png             0           False            0.294081
# 15  tic23.png             0           False            0.277036
# 16  tic24.png             0           False            0.259624
# 17  tic25.png             0           False            0.262095
# 18  tic26.png             0           False            0.266171
# 19  tic27.png             1           False            0.347626
# 20  tic28.png             1           False            0.197812
# 21  tic29.png             1           False            0.188444
# 22   tic3.png             1           False            0.276970
# 23  tic30.png             0           False            0.399152
# 24  tic31.png             0           False            0.194129
# 25  tic32.png             0           False            0.215850
# 26  tic33.png             0           False            0.293606
# 27  tic34.png             0           False            0.317004
# 28   tic4.png             0           False            0.249459
# 29   tic5.png             0           False            0.283520
# 30   tic6.png             1           False            0.232755
# 31   tic7.png             0           False            0.212342
# 32   tic8.png             0           False            0.176752
# 33   tic9.png             0           False            0.246414
# Model metrics saved to: model_metrics_resnet_2024-06-13_09-53-15.csv
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
